# %%
from transformers import BertTokenizer

# %%
tokenizer = BertTokenizer.from_pretrained(
    "bert-base-uncased"
)

print(tokenizer.tokenize("Indian tutorials is a game changer!"))
# ## lagane ka reason context maintain karna hai — ki ye token kisi word ka continuation/part hai, naya word nahi:
'''
------------------------------------------------------------------------
| Token | Matlab                                                       |
| ----- | ------------------------------------------------------------ |
| play  | Naya word shuru ho raha hai cran.r-project                   |
| ##ing | Pichle token ka continuation hai (naya word nahi) muegenai+1 |
------------------------------------------------------------------------
'''
# Out:
# ['indian', 'tutor', '##ials', 'is', 'a', 'game', 'change', '##r', '!']
