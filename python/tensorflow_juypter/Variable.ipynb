# %%
import tensorflow as tf

# %%
arr = tf.Variable([15,5,91,18,11,93])
arr
# Out:
# <tf.Variable 'Variable:0' shape=(6,) dtype=int32, numpy=array([15,  5, 91, 18, 11, 93])>

# %%
arr1 = tf.Variable([1,2,2,4,5])
arr2 = tf.Variable([6,7,8,9,10])
print(arr1)
print(arr2)
# Out:
# <tf.Variable 'Variable:0' shape=(5,) dtype=int32, numpy=array([1, 2, 2, 4, 5])>
# <tf.Variable 'Variable:0' shape=(5,) dtype=int32, numpy=array([ 6,  7,  8,  9, 10])>

# %%
import tensorflow as tf

a = tf.Variable([1, 2, 3])
b = tf.Variable([4, 5, 6])

print(a)
print(b)
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([1, 2, 3])>
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([4, 5, 6])>
