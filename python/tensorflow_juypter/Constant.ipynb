# %%
import tensorflow as tf

# %%
tfc = tf.constant(1)
tfc
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
tf.constant(2)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tfc = tf.constant(1)
tfc
tf.constant(2)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>
