# %%
import pandas as pd

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://en.wikipedia.org/wiki/List_of_highest-grossing_Indian_films"
headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(url, headers=headers)
response.raise_for_status()

htmlData = pd.read_html(StringIO(response.text))
print(htmlData[0])  # First table
# Out:
#     Rank                         Title        Worldwide gross      Language  \
# 0      1                        Dangal     ₹1,968–2,054 crore         Hindi
# 1      2       Dhurandhar: The Revenge        ₹1,852.10 crore         Hindi
# 2      3   Baahubali 2: The Conclusion        ₹1,810.43 crore        Telugu
# 3      4            Pushpa 2: The Rule     ₹1,642–1,800 crore        Telugu
# 4      5                    Dhurandhar  ₹1,350.83–1,428 crore         Hindi
# 5      6                           RRR     ₹1,300–1,387 crore        Telugu
# 6      7                KGF: Chapter 2     ₹1,200–1,250 crore       Kannada
# 7      8                         Jawan        ₹1,148.32 crore         Hindi
# 8      9                       Pathaan        ₹1,050.30 crore         Hindi
# 9     10                 Kalki 2898 AD     ₹1,042–1,100 crore        Telugu
# 10    11                        Animal          ₹917.82 crore         Hindi
# 11    12             Bajrangi Bhaijaan   ₹900.90–969.06 crore         Hindi
# 12    13                       Stree 2          ₹874.58 crore         Hindi
# 13    14              Secret Superstar      ₹858.43–966 crore         Hindi
# 14    15            Kantara: Chapter 1         ₹850–900 crore       Kannada
# 15    16                       Chhaava      ₹797.34–809 crore         Hindi
# 16    17                            PK   ₹750.60–769.89 crore         Hindi
# 17    18                           2.0      ₹699.89–800 crore         Tamil
# 18    19                       Gadar 2          ₹691.08 crore         Hindi
# 19    20                        Sultan   ₹615.71–623.33 crore         Hindi
# 20    21    Salaar: Part 1 – Ceasefire         ₹614–702 crore        Telugu
# 21    22                        Jailer         ₹605–650 crore         Tamil
# 22    23      Baahubali: The Beginning      ₹599.72–650 crore  Telugu/Tamil
# 23    24                           Leo         ₹595–615 crore         Tamil
# 24    25                         Sanju          ₹586.85 crore         Hindi
# 25    26                      Saiyaara          ₹579.23 crore         Hindi
# 26    27               Tiger Zinda Hai          ₹565.19 crore         Hindi
# 27    28                     Padmaavat   ₹563.55–571.98 crore         Hindi
# 28    29                       Dhoom 3   ₹556.74–558.42 crore         Hindi
# 29    30                        Coolie         ₹514–675 crore         Tamil
# 30    31                           War   ₹474.79–475.62 crore         Hindi
# 31    32                         Dunki          ₹470.60 crore         Hindi
# 32    33                       Tiger 3          ₹466.63 crore         Hindi
# 33    34                      Border 2          ₹464.50 crore         Hindi
# 34    35            Ponniyin Selvan: I         ₹450–500 crore         Tamil
# 35    36                     Andhadhun   ₹444.48–456.89 crore         Hindi
# 36    37      The Greatest of All Time         ₹440–460 crore         Tamil
# 37    38                        Vikram         ₹424–500 crore         Tamil
# 38    39             Bhool Bhulaiyaa 3          ₹423.85 crore         Hindi
# 39    40                         Saaho         ₹419–439 crore  Telugu/Hindi
# 40    41  Brahmāstra: Part One – Shiva   ₹418.80–430.77 crore         Hindi
# 41    42                       Kantara         ₹400–450 crore       Kannada
# 42    43                      3 Idiots      ₹400.61–460 crore         Hindi
# 43    44               Chennai Express   ₹395.92–424.54 crore         Hindi
# 44    45                      Krrish 3          ₹393.37 crore         Hindi
# 45    46                     Adipurush          ₹392.70 crore  Hindi/Telugu
# 46    47                        Simmba   ₹391.68–400.19 crore         Hindi
# 47    48                 Singham Again          ₹389.64 crore         Hindi
# 48    49                Devara: Part 1         ₹380–521 crore        Telugu
# 49    50              Pushpa: The Rise             ₹360 crore        Telugu
#
#     Year      Ref.
# 0   2016       [b]
# 1   2026      [16]
# 2   2017       [c]
# 3   2024       [d]
# 4   2025  [21][22]
# 5   2022       [e]
# 6   2022       [f]
# 7   2023      [38]
# 8   2023      [39]
# 9   2024       [g]
# 10  2023      [48]
# 11  2015       [h]
# 12  2024      [52]
# 13  2017       [i]
# 14  2025       [k]
# 15  2025       [l]
# 16  2014       [m]
# 17  2018       [n]
# 18  2023      [65]
# 19  2016       [o]
# 20  2023       [p]
# 21  2023       [q]
# 22  2015       [r]
# 23  2023       [s]
# 24  2018      [77]
# 25  2025      [78]
# 26  2017      [79]
# 27  2018       [t]
# 28  2013       [u]
# 29  2025       [v]
# 30  2019       [w]
# 31  2023      [90]
# 32  2023      [91]
# 33  2026      [92]
# 34  2022       [x]
# 35  2018       [y]
# 36  2024       [z]
# 37  2022      [aa]
# 38  2024     [104]
# 39  2019      [ab]
# 40  2022      [ac]
# 41  2022      [ad]
# 42  2009      [ae]
# 43  2013      [af]
# 44  2013     [112]
# 45  2023     [113]
# 46  2018      [ag]
# 47  2024     [115]
# 48  2024      [ah]
# 49  2021     [120]
