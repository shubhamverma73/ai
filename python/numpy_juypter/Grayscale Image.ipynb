# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.array([
    [255, 128, 64, 0, 255],
    [200, 100, 50, 25, 0],
    [255, 255, 255, 0, 0],
    [50, 100, 150, 200, 250],
    [0, 50, 100, 150, 200],
    [30, 75, 145, 150, 255]
])

plt.imshow(image, cmap='gray')  # grayscale image dikhayega
plt.axis('off')                  # axis numbers hatayega
plt.show()
print(image.ndim)
print(len(image))
print(image.shape)
# Out:
# 2
# 6
# (6, 5)
