# %%
a = [1, 2, 3]
b = [4, 5, 6]

# manually add karna padega
result = [a[i] + b[i] for i in range(3)]
print(result)
# Out:
# [5, 7, 9]

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

response = a + b   # direct addition
print(response)
# Out:
# [5 7 9]
