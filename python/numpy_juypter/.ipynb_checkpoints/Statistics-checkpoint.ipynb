# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40, 50])

print(arr.max())
print(arr.min())
print(arr.sum())
print("Other functions")
print(np.mean(arr))
print(np.median(arr))
# Out:
# 50
# 10
# 150
# Other functions
# 30.0
# 30.0

# %%
import numpy as np

a = np.array([1, 2, 3])

print(a * 10 + 5)
# here first it will calculate a * 10 than + 5
# 1 * 10 = 10 + 5 = 15
# 2 * 10 = 20 + 5 = 25
# 3 * 10 = 30 +5 = 35
# Out:
# [15 25 35]
