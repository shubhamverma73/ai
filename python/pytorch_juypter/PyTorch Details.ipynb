# %%
import torch

print(torch.__version__)
# Out:
# 2.12.0+cpu

# %%
import torch

print(torch.cuda.is_available())
# Out:
# False

# %%
import torch

x = torch.tensor([1, 2, 3])

print(x)
print(type(x))
# Out:
# tensor([1, 2, 3])
# <class 'torch.Tensor'>

# %%
x = torch.tensor([1,2,3])

print(x.device)
# Out:
# cpu

# %%
import torch

x = torch.ones((2,3))

print(x)
print(x.shape)
print(x.numel())
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])
# torch.Size([2, 3])
# 6
